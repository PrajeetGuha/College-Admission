# %%
from win32api import GetSystemMetrics
import tkinter as tk
from tkinter import ttk
from tkinter import *
from PIL import Image,ImageTk

date=['01','02','03','04','05','06','07','08','09']
month=['01','02','03','04','05','06','07','08','09','10','11','12']
year=['98','99','00','01','02','03','04','05','06','07','08','09']
dept=['CSE','IT','ECE','EE']

for i in range(10,32):
    date.append(i)
    if i<=21:
        year.append(i)
        
width = GetSystemMetrics(0)
height = GetSystemMetrics(1)
root = tk.Tk()
root.resizable(0,0)
root.state('zoomed')
dimension = f'{width}x{height}'
root.geometry(dimension)

main_Canvas = tk.Canvas(root,height = height, width = width, highlightthickness = 0)
main_Canvas.pack(padx = 0, pady = 0,fill = 'both', expand = True)
font = f'Arial {int(0.013*height)} bold'

main_Canvas1=tk.Canvas(main_Canvas,height =0.050*height, width =0.055*width)
main_Canvas1.place(x=0.03*height,y=0.03*height)
back_button= tk.Button(main_Canvas1, text = 'Log Out ',fg ='white',bg ='blue',font = font, command = None)
main_Canvas1.create_window(width/20,height/20, window =  back_button)
back_button.pack()

background_image = Image.open('background_image_2.jpg').resize((width, height))
tk_background_Image = ImageTk.PhotoImage(background_image)

main_Canvas.create_image(width/2, height/2, image = tk_background_Image)
main_Canvas.image = tk_background_Image

frame = tk.Frame(main_Canvas)
main_Canvas.create_window(width/2.0217,height/1.89,window=frame)
main_Canvas2=tk.Canvas(frame,height =0.88*height, width =0.992*width,scrollregion = (0,0,0,4400))
main_Canvas2.pack(side='left',expand=True,fill='both')

scroll = tk.Scrollbar(frame,orient='vertical',command = main_Canvas2.yview)
scroll.pack(side='left',fill='y')
main_Canvas2.config(yscrollcommand = scroll.set)

# main_Canvas2.create_window(400,400,window=tk.Label(main_Canvas2,text = 'ABCD'))

#Ishita's part
frame=Canvas(main_Canvas2,relief="solid",borderwidth=1,width=0.80*width,height=0.21*height)
main_Canvas2.create_window(0.42*width,0.12*height,window=frame)

name=Label(frame,text="FIRST NAME :",bg="powderblue",font="Arial 12 bold")
name.place(x=0.010*width,y=0.020*height)
fentry1=StringVar() #1st name var
fentry1=ttk.Entry(frame,font="Arial 12")
fentry1.place(x=0.195*height,y=0.020*height,width=0.25*width)

name1=Label(frame,text="LAST NAME :",bg="powderblue",font="Arial 12 bold")
name1.place(x=0.40*width,y=0.020*height)
fentry2=StringVar()  #last name var
fentry2=ttk.Entry(frame,font="Arial 12 bold")
fentry2.place(x=0.5*width,y=0.020*height,width=0.25*width)

name2=Label(frame,text="FATHER'S NAME :",bg="powderblue",font="Arial 12 bold")
name2.place(x=0.01*width,y=0.085*height)
fentry3=StringVar()  # father name var
fentry3=ttk.Entry(frame,font="Arial 12 bold")
fentry3.place(x=0.14*width,y=0.085*height,width=0.55*width)

name3=Label(frame,text="MOTHER'S NAME :",bg="powderblue",font="Arial 12 bold")
name3.place(x=0.01*width,y=0.15*height)
fentry4=StringVar()   # mother name var
fentry4=ttk.Entry(frame,font="Arial 12 bold")
fentry4.place(x=0.14*width,y=0.15*height,width=0.55*width)




#Aniket's Part
f1=Canvas(main_Canvas2,relief="solid",borderwidth=1,width=0.33*width,height=0.08*height)
main_Canvas2.create_window(0.22*width,0.3*height,window=f1)
l5=Label(f1,text="GENDER:",font="Arial 12 bold",bg="skyblue")
l5.place(x=0.010*width,y=0.02*height)
ee5=IntVar()   # gender var
r1=Radiobutton(f1,text="MALE",font="Arial 12",bg="skyblue",variable=ee5,value=1)
r1.place(x=0.09*width,y=0.02*height)
r2=Radiobutton(f1,text="FEMALE",font="Arial 12",bg="skyblue",variable=ee5,value=2)
r2.place(x=0.157*width,y=0.02*height)
r3=Radiobutton(f1,text="OTHERS",font="Arial 12",bg="skyblue",variable=ee5,value=3)
r3.place(x=0.24*width,y=0.02*height)

f2=Frame(main_Canvas2,relief="solid",borderwidth=1)
f2.place(x=0.374*width,y=0.25*height,width=0.21*width,height=0.08*height)
l=Label(f2,text="DOB:",font="Arial 12 bold",bg="skyblue")
l.place(x=0.01*width,y=0.02*height)
d1=ttk.Combobox(f2,value=date,width=int(0.0035*width))   # date var of dob
d1.place(x=0.070*width,y=0.02*height)
d1.set("DD")
m1=ttk.Combobox(f2,value=month,width=int(0.0036*width))   # month var of dob
m1.place(x=0.11*width,y=0.02*height)
m1.set("MM")
y1=ttk.Combobox(f2,value=year,width=int(0.0036*width))   # year var of dob
y1.place(x=0.15*width,y=0.02*height)
y1.set("YY")

f3=Frame(main_Canvas2,relief="solid",borderwidth=1)
f3.place(x=0.61*width,y=0.25*height,width=0.21*width,height=0.08*height)
l2=Label(f3,text="DEPARTMENT:",font="Arial 12 bold",bg="skyblue")
l2.place(x=0.016*width,y=0.02*height)
de=ttk.Combobox(f3,value=dept,width=int(0.004*width))   # department var
de.place(x=0.13*width,y=0.02*height)

#s=Scrollbar(main_Canvas2)
#s.place(x=1263,y=20)



#Shounak's Part
f4=Frame(main_Canvas2,relief="solid",borderwidth=1)
f4.place(x=0.02*width,y=0.35*height,width=0.80*width,height=0.22*height)
Canvas_Shounak=tk.Canvas(f4,width=0.80*width,height=0.22*height)
Canvas_Shounak.pack()

ourMessage ="GUARDIAN'S PHONE NUMBER :-"   #guardian's phn number
messageVar = Label(Canvas_Shounak,text=ourMessage,font="Arial 12 bold",bg="skyblue")
Canvas_Shounak.create_window(0.187*height,0.045*height,window=messageVar)
v1=tk.StringVar()
e1 = ttk.Entry(Canvas_Shounak,font="Arial 12 bold",width=int(0.045*height),textvariable=v1)
Canvas_Shounak.create_window(0.59*height,0.045*height,window=e1)
v1.set("+91 ")
V1=v1.get()
def guardian_phn_no(V1):
    try:
        n=0
        for i in V1:
            k=int(i)
            n+=1
        if n==10:
            return True
        else:
            return False
    except:
        return False
if False:
    v1.set('+91 ')
ourMessage1 ="STUDENT'S PHONE NUMBER :-"   #student's phn number
messageVar1 = Label(Canvas_Shounak,text=ourMessage1,font="Arial 12 bold",bg="skyblue")
Canvas_Shounak.create_window(0.183*height,0.107*height,window=messageVar1)
v2=tk.StringVar()
e2 = ttk.Entry(Canvas_Shounak,font="Arial 12 bold",width=int(0.045*height),textvariable=v2)
Canvas_Shounak.create_window(0.58*height,0.107*height,window=e2)
v2.set("+91 ")
V2=v2.get()
def student_phn_no(V2):
    try:
        n=0
        for i in V2:
            k=int(i)
            n+=1
        if n==10:
            return True
        else:
            return False
    except:
        return False
if False:
    v2.set('+91 ')
ourMessage2 ="DOMICILE CERTIFICATE :-"
messageVar2 = tk.Label(Canvas_Shounak,text=ourMessage2,font="Arial 12 bold",bg="skyblue")
Canvas_Shounak.create_window(0.156*height,0.169*height,window=messageVar2)
comboExample = ttk.Combobox(Canvas_Shounak,
                            values=[
                                    "Yes",
                                    "No"],width=int(0.0036*width))
Canvas_Shounak.create_window(0.348*height,0.168*height,window=comboExample)
comboExample.current(1)
'''

c.create_line(20,128,300,128)
c.create_line(20,128,20,178)
c.create_line(20,178,300,178)
c.create_line(300,178,300,127)
c.create_window(87,153,window=messageVar2)

c.create_window(225,153,window=comboExample)
'''
default_field_values = {'Name':'','Email':'janowarsumideb@goru.com','Phone Number':'', 'Gender': '', 'Present Address': '', 'Permanent Address': '', 'Father_name':'', 'Mother_name':'', 'Father phone':'', 'Mother phone':'', 'X Total Score':'', 'X Percentage':'', 'XII Total Score':'', 'XII Percentage':'', 'X Board':'', 'XII Board':''}
root.mainloop()

# %%
from tkinter import *
from tkinter import ttk

win=Tk()

wrapper1=LabelFrame(win)
wrapper2=LabelFrame(win)

mycanvas=Canvas(wrapper1)
mycanvas.pack(side=LEFT,fill="both",expand="yes")

yscrollbar=ttk.Scrollbar(wrapper1,orient="vertical",command=mycanvas.yview)
yscrollbar.pack(side=RIGHT,fill="y")

mycanvas.configure(yscrollcommand=yscrollbar.set)

myframe=Frame(mycanvas)
mycanvas.create_window((0,0),window=myframe,anchor="nw")

mycanvas.bind("<Configure>",lambda e:mycanvas.configure(scrollregion=mycanvas.bbox("all")))

wrapper1.pack(fill="both",expand="yes",padx=10,pady=10)
wrapper1.pack(fill="both",expand="yes",padx=10,pady=10)

for i in range(50):
    Button(myframe,text="My Button - "+str(i)).place(x=i+100,y=100-2*i)
    
win.geometry("500x500")
win.resizable(False,False)
win.title("MyScrollbar")
win.mainloop()
